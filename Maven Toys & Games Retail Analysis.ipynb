# %%
import pandas as pd

# Load Data into Pandas Dataframe

products = pd.read_csv(r"C:\Users\biswa\Downloads\Maven Toys & Games Project file\Datasets\Products.csv")

stores = pd.read_csv(r"C:\Users\biswa\Downloads\Maven Toys & Games Project file\Datasets\stores.csv")

date_table = pd.read_csv(r"C:\Users\biswa\Downloads\Maven Toys & Games Project file\Datasets\Calender.csv")

inventory = pd.read_csv(r"C:\Users\biswa\Downloads\Maven Toys & Games Project file\Datasets\inventory.csv")

sales = pd.read_csv(r"C:\Users\biswa\Downloads\Maven Toys & Games Project file\Datasets\Sales.csv")

# %%
# Printing First Five Rows/Records for products table

products.head()
# Out:
#    Product_ID      Product_Name Product_Category  Product_Cost  Product_Price
# 0         1.0     Action Figure             Toys          9.99          15.99
# 1         2.0    Animal Figures             Toys          9.99          12.99
# 2         3.0   Barrel O' Slime     Art & Crafts          1.99           3.99
# 3         4.0  Chutes & Ladders            Games          9.99          12.99
# 4         5.0  Classic Dominoes            Games          7.99           9.99

# %%
# Printing First Five Rows/Records for stores table

stores.head()
# Out:
#    Store_ID                Store_Name   Store_City Store_Location  \
# 0         1  Maven Toys Guadalajara 1  Guadalajara    Residential
# 1         2    Maven Toys Monterrey 1    Monterrey    Residential
# 2         3  Maven Toys Guadalajara 2  Guadalajara     Commercial
# 3         4     Maven Toys Saltillo 1     Saltillo       Downtown
# 4         5       Maven Toys La Paz 1       La Paz       Downtown
#
#   Store_Open_Date
# 0      1992-09-18
# 1      1995-04-27
# 2      1999-12-27
# 3      2000-01-01
# 4      2001-05-31

# %%
# Printing First Five Rows/Records for inventory table

inventory.head()
# Out:
#    Store_ID  Product_ID  Stock_On_Hand
# 0         1           1             27
# 1         1           2              0
# 2         1           3             32
# 3         1           4              6
# 4         1           5              0

# %%
# Printing First Five Rows/Records for date table

date_table.head()
# Out:
#   Date_Column Month_column Quarter   Week_day  Year Week_number
# 0  2022-01-01      January   Qtr-1   Saturday  2022      Week-1
# 1  2022-01-02      January   Qtr-1     Sunday  2022      Week-2
# 2  2022-01-03      January   Qtr-1     Monday  2022      Week-2
# 3  2022-01-04      January   Qtr-1    Tuesday  2022      Week-2
# 4  2022-01-05      January   Qtr-1  Wednesday  2022      Week-2

# %%
# Printing First Five Rows/Records for sales table

sales.head()
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units
# 0        1  2022-01-01        24           4      1
# 1        2  2022-01-01        28           1      1
# 2        3  2022-01-01         6           8      1
# 3        4  2022-01-01        48           7      1
# 4        5  2022-01-01        44          18      1

# %% [markdown]
# # Data Preperation/ Cleaning Section: -

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_ID        35 non-null     float64
#  1   Product_Name      35 non-null     object
#  2   Product_Category  35 non-null     object
#  3   Product_Cost      35 non-null     float64
#  4   Product_Price     35 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 1.5+ KB

# %% [markdown]
# Its Clearly Showing that Products table have no null entries.

# %%
# Check for duplicate Records in products table/Dataframe

products.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# dtype: bool

# %%
# Removing duplicated Records from products table/Dataframe

products.drop_duplicates(inplace = True)

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store_ID         50 non-null     int64
#  1   Store_Name       50 non-null     object
#  2   Store_City       50 non-null     object
#  3   Store_Location   50 non-null     object
#  4   Store_Open_Date  50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %% [markdown]
#  Similarly Its Clearly Showing that stores table have no null entries.

# %%
# Check for duplicate records in the stores table / Dataframe
stores.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
# Removing Duplicate Records from store table /Dataframe

stores.drop_duplicates(inplace = True)

# %%
# Convert stores table Store_Open_Date columns datatypes to datetime.

stores['Store_Open_Date'] = pd.to_datetime(stores['Store_Open_Date'] , errors = 'coerce',format = '%Y-%m-%d')

# %%
stores.dtypes
# Out:
# Store_ID                    int64
# Store_Name                 object
# Store_City                 object
# Store_Location             object
# Store_Open_Date    datetime64[ns]
# dtype: object

# %%
inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1593 entries, 0 to 1592
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Store_ID       1593 non-null   int64
#  1   Product_ID     1593 non-null   int64
#  2   Stock_On_Hand  1593 non-null   int64
# dtypes: int64(3)
# memory usage: 37.5 KB

# %% [markdown]
# Also my inventory table have no null entries

# %%
# Check for duplicate Records in inventory table/ Dataframe

inventory.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1588    False
# 1589    False
# 1590    False
# 1591    False
# 1592    False
# Length: 1593, dtype: bool

# %%
# Removing Duplicate Records from Inventory table /Dataframe

inventory.drop_duplicates(inplace = True)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829262 entries, 0 to 829261
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Sale_ID     829262 non-null  int64
#  1   Date        829262 non-null  object
#  2   Store_ID    829262 non-null  int64
#  3   Product_ID  829262 non-null  int64
#  4   Units       829262 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 31.6+ MB

# %% [markdown]
# Again sales table have no null entries

# %%
# Check for Duplicate Records in sales table / Dataframe

sales.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 829257    False
# 829258    False
# 829259    False
# 829260    False
# 829261    False
# Length: 829262, dtype: bool

# %%
# Rmoving Duplicates Records from Sales table / Dataframe
sales.drop_duplicates(inplace = True)

# %%
# Covert sales table Date columns datatypes to datetime

sales['Date'] = pd.to_datetime(sales['Date'] , errors = 'coerce' , format = '%Y-%m-%d')

# %%
sales.dtypes
# Out:
# Sale_ID                int64
# Date          datetime64[ns]
# Store_ID               int64
# Product_ID             int64
# Units                  int64
# dtype: object

# %%
date_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date_Column   611 non-null    object
#  1   Month_column  611 non-null    object
#  2   Quarter       611 non-null    object
#  3   Week_day      611 non-null    object
#  4   Year          611 non-null    int64
#  5   Week_number   611 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 28.8+ KB

# %%
# Renaming date_table,  Date_Column & Month_column columns

date_table.rename(columns = {'Date_Column':'Date',
                            'Month_column':'Month_Name'} , inplace = True)

# %%
# Convert Date Column into datetime format

date_table['Date'] = pd.to_datetime(date_table['Date'] , errors = 'coerce',format ='%Y-%m-%d')

# %%
# Add One More Column in the date_table dataframe 

date_table['Month_Number'] = date_table['Date'].dt.month

# %%
date_table.dtypes
# Out:
# Date            datetime64[ns]
# Month_Name              object
# Quarter                 object
# Week_day                object
# Year                     int64
# Week_number             object
# Month_Number             int32
# dtype: object

# %%
sales['Date'].sort_values()
# Out:
# 0        2022-01-01
# 779      2022-01-01
# 778      2022-01-01
# 777      2022-01-01
# 776      2022-01-01
#             ...
# 827914   2023-09-30
# 827913   2023-09-30
# 827912   2023-09-30
# 827925   2023-09-30
# 829261   2023-09-30
# Name: Date, Length: 829262, dtype: datetime64[ns]

# %%
date_table['Date']
# Out:
# 0     2022-01-01
# 1     2022-01-02
# 2     2022-01-03
# 3     2022-01-04
# 4     2022-01-05
#          ...
# 606   2023-09-26
# 607   2023-09-27
# 608   2023-09-28
# 609   2023-09-29
# 610   2023-09-30
# Name: Date, Length: 611, dtype: datetime64[ns]

# %% [markdown]
# # Analytical business Problems:-
#
# # 1. Sales Performance Analysis Section:-

# %%
# What are the total sales revenue and profit generated by each store? 

# Merge the 'stores' and 'sales' tables on the 'Store_ID' column using an inner join.
# This combines store information with sales data for each store.
store_sales = stores.merge(sales, how='inner', on='Store_ID')

# Merge the resulting DataFrame with the 'products' table on the 'Product_ID' column using an inner join.
# This adds product information (e.g., price, cost) to the sales data.
store_sales_revenue = store_sales.merge(products, how='inner', on='Product_ID')

# Calculate the revenue for each sale by multiplying the product price by the number of units sold.
# This creates a new column called 'Revenue' in the DataFrame.
store_sales_revenue['Revenue'] = (store_sales_revenue['Product_Price'] * store_sales_revenue['Units'])

# Calculate the profit for each sale by subtracting the total cost from the total revenue.
# The total cost is calculated by multiplying the product cost by the number of units sold.
# This creates a new column called 'Profit' in the DataFrame.
store_sales_revenue['Profit'] = (store_sales_revenue['Revenue'] - (store_sales_revenue['Product_Cost'] * store_sales_revenue['Units']))

# Group the DataFrame by 'Store_Name' and calculate the total revenue for each store.
# The result is a new DataFrame with two columns: 'Store_Name' and the sum of 'Revenue' for each store.
df = store_sales_revenue.groupby('Store_Name')['Revenue'].sum().reset_index()

# Rename the columns in the resulting DataFrame for clarity.
# The 'Revenue' column is renamed to 'Total_Sales_Revenue(US Dollars $)'.
df.columns = ['Store_Name', 'Total_Sales_Revenue(US Dollars $)']

# Sort the DataFrame by the 'Total_Sales_Revenue(US Dollars $)' column in descending order.
# This shows the stores with the highest total sales revenue at the top.
df.sort_values(by='Total_Sales_Revenue(US Dollars $)', ascending=False)
# Out:
#                        Store_Name  Total_Sales_Revenue(US Dollars $)
# 9   Maven Toys Ciudad de Mexico 2                          554553.43
# 17       Maven Toys Guadalajara 3                          449354.91
# 8   Maven Toys Ciudad de Mexico 1                          433556.21
# 43            Maven Toys Toluca 1                          411157.32
# 30         Maven Toys Monterrey 2                          372998.82
# 18       Maven Toys Guadalajara 4                          348466.64
# 24        Maven Toys Hermosillo 3                          344846.64
# 48            Maven Toys Xalapa 2                          344307.04
# 10  Maven Toys Ciudad de Mexico 3                          337424.66
# 39          Maven Toys Saltillo 1                          330408.90
# 32         Maven Toys Monterrey 4                          325073.50
# 11  Maven Toys Ciudad de Mexico 4                          323957.71
# 23        Maven Toys Hermosillo 2                          323427.02
# ...

# %%
# Calculating Top 10 Stores Based on Sales Revenue

top_10_stores = df.sort_values(by = 'Total_Sales_Revenue(US Dollars $)' , ascending = False).head(10)

top_10_stores
# Out:
#                        Store_Name  Total_Sales_Revenue(US Dollars $)
# 9   Maven Toys Ciudad de Mexico 2                          554553.43
# 17       Maven Toys Guadalajara 3                          449354.91
# 8   Maven Toys Ciudad de Mexico 1                          433556.21
# 43            Maven Toys Toluca 1                          411157.32
# 30         Maven Toys Monterrey 2                          372998.82
# 18       Maven Toys Guadalajara 4                          348466.64
# 24        Maven Toys Hermosillo 3                          344846.64
# 48            Maven Toys Xalapa 2                          344307.04
# 10  Maven Toys Ciudad de Mexico 3                          337424.66
# 39          Maven Toys Saltillo 1                          330408.90

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Set the style for the plot
sns.set_style('ticks')

# Create a figure with a specific size
plt.figure(figsize=(12, 8))

# Create a horizontal bar plot
ax = sns.barplot(
    data=top_10_stores,
    y='Store_Name',
    x='Total_Sales_Revenue(US Dollars $)',
    orient='h',
    color='skyblue',
    edgecolor='black',
    width=0.7
)

# Add data labels to each bar
for bar in ax.patches:
    width = bar.get_width()
    ax.text(
        width + 5000,  # Add a small offset to the right of the bar
        bar.get_y() + bar.get_height() / 2,  # Center vertically on the bar
        f'${width:,.0f}',  # Format with dollar sign and commas
        ha='left',  # Horizontal alignment: left
        va='center',  # Vertical alignment: center
        fontweight='bold',  # Bold text
    )

# Add a title to the plot
plt.title("Top 10 Stores Based On Total Sales Revenue", fontsize=16, fontweight='bold')

# Label the x-axis and y-axis with bold font
plt.xlabel("Total Sales Revenue in US Dollars($)", fontsize=14, fontweight='bold')
plt.ylabel("Store Name", fontsize=14, fontweight='bold')

# Make the x-axis and y-axis tick labels bold
plt.xticks(fontweight='bold')  # Bold x-axis tick labels
plt.yticks(fontweight='bold')  # Bold y-axis tick labels

# Adjust layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %%
df1 = store_sales_revenue.groupby('Store_Name')['Profit'].sum().reset_index()

df1.columns = ['Store_Name' , 'Total_Profit(US Dollars $)']

df1.sort_values(by = 'Total_Profit(US Dollars $)' , ascending = False)
# Out:
#                        Store_Name  Total_Profit(US Dollars $)
# 9   Maven Toys Ciudad de Mexico 2                    169856.0
# 17       Maven Toys Guadalajara 3                    121571.0
# 8   Maven Toys Ciudad de Mexico 1                    111296.0
# 30         Maven Toys Monterrey 2                    106783.0
# 43            Maven Toys Toluca 1                    104612.0
# 18       Maven Toys Guadalajara 4                    102178.0
# 24        Maven Toys Hermosillo 3                     98825.0
# 27          Maven Toys Mexicali 1                     97206.0
# 39          Maven Toys Saltillo 1                     94252.0
# 10  Maven Toys Ciudad de Mexico 3                     94021.0
# 33           Maven Toys Morelia 1                     90484.0
# 11  Maven Toys Ciudad de Mexico 4                     90385.0
# 48            Maven Toys Xalapa 2                     88637.0
# 1           Maven Toys Campeche 1                     88248.0
# ...

# %%
top_10_profitable_stores = df1.sort_values(by = 'Total_Profit(US Dollars $)' , ascending = False).head(10)

# Visualize Top 10 Profitable Stores

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df1 is your DataFrame, sort and select top 10 profitable stores
# Replace df1 with your actual DataFrame if needed
# top_10_profitable_stores = df1.sort_values(by='Total_Profit(US Dollars $)', ascending=False).head(10)

# Set the style for the plot
sns.set_style('ticks')

# Create a figure with a specific size
plt.figure(figsize=(12, 8))

# Create a horizontal bar plot
ax = sns.barplot(
    data=top_10_profitable_stores,
    y='Store_Name',
    x='Total_Profit(US Dollars $)',
    orient='h',
    color='green',
    edgecolor='black',
    width=0.6
)

# Add data labels to each bar
for bar in ax.patches:
    width = bar.get_width()
    ax.text(
        width + 5000,  # Add a small offset to the right of the bar
        bar.get_y() + bar.get_height() / 2,  # Center vertically on the bar
        f'${width:,.0f}',  # Format with dollar sign and commas
        ha='left',  # Horizontal alignment: left
        va='center',  # Vertical alignment: center
        fontweight='bold',  # Bold text
    )

# Add a title to the plot
plt.title("Top 10 Stores Based On Total Profit", fontsize=16, fontweight='bold')

# Label the x-axis and y-axis with bold font
plt.xlabel("Total Profit in US Dollars($)", fontsize=14, fontweight='bold')
plt.ylabel("Store Name", fontsize=14, fontweight='bold')

# Make the x-axis and y-axis tick labels bold
plt.xticks(fontweight='bold')  # Bold x-axis tick labels
plt.yticks(fontweight='bold')  # Bold y-axis tick labels

# Adjust layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Which products are the top-selling and least-selling across all stores?

# Merge the 'sales' and 'products' tables on the 'Product_ID' column using an inner join.
# This combines sales data with product information for each product sold.
product_sales = sales.merge(products, how='inner', on='Product_ID')

# Group the merged DataFrame by 'Product_Name' and calculate the total units sold for each product.
# The result is a new DataFrame with two columns: 'Product_Name' and the sum of 'Units' sold for each product.
product_units_sold = product_sales.groupby('Product_Name')['Units'].sum().reset_index()

# Rename the columns in the resulting DataFrame for clarity.
# The 'Units' column is renamed to 'Total_Quantity_Sold'.
product_units_sold.columns = ['Product_Name', 'Total_Quantity_Sold']

# Sort the DataFrame by 'Total_Quantity_Sold' in descending order and select the top 10 products.
# This gives the top 10 best-selling products based on the total quantity sold.
top_selling_products = product_units_sold.sort_values(by='Total_Quantity_Sold', ascending=False).head(10)

# Display the resulting DataFrame containing the top 10 best-selling products.
top_selling_products
# Out:
#        Product_Name  Total_Quantity_Sold
# 5         Colorbuds               104368
# 24      PlayDoh Can               103128
# 2   Barrel O' Slime                91663
# 7     Deck Of Cards                84034
# 18       Magic Sand                60598
# 30     Splash Balls                60248
# 17      Lego Bricks                59737
# 0     Action Figure                57958
# 29     Rubik's Cube                45672
# 1    Animal Figures                39089

# %%
# Visualize Top 10 Best Selling Products Based on Quantity Sold

import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for the plot
sns.set_style('ticks')

# Create a figure with a specific size
plt.figure(figsize=(14, 9))

# Create a horizontal bar plot
ax = sns.barplot(
    data=top_selling_products,
    y='Product_Name',
    x='Total_Quantity_Sold',
    orient='h',
    color='hotpink',
    edgecolor='black',
    width=0.7
)

# Add data labels to each bar
for bar in ax.patches:
    width = bar.get_width()
    ax.text(
        width + 50,  # Add a small offset to the right of the bar
        bar.get_y() + bar.get_height() / 2,  # Center vertically on the bar
        f'{int(width):,}',  # Format with commas, no decimals
        ha='left',  # Horizontal alignment: left
        va='center',  # Vertical alignment: center
        fontweight='bold',  # Bold text
    )

# Add a title to the plot
plt.title("Top 10 Best Selling Products", fontsize=16, fontweight='bold')

# Label the x-axis and y-axis with bold font
plt.xlabel("Total Quantity Sold", fontsize=14, fontweight='bold')
plt.ylabel("Product Name", fontsize=14, fontweight='bold')

# Make the x-axis and y-axis tick labels bold
plt.xticks(fontweight='bold')  # Bold x-axis tick labels
plt.yticks(fontweight='bold')  # Bold y-axis tick labels

# Adjust layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Calculating Least Selling Products based on Quantity Sold

least_selling_products = product_units_sold.sort_values(by = 'Total_Quantity_Sold' , ascending = False).tail(10)

least_selling_products
# Out:
#              Product_Name  Total_Quantity_Sold
# 31  Supersoaker Water Gun                 6793
# 32             Teddy Bear                 6416
# 25        PlayDoh Playset                 6298
# 28             Plush Pony                 5488
# 4        Classic Dominoes                 4471
# 27               Playfoam                 4158
# 3        Chutes & Ladders                 3829
# 21               Monopoly                 3385
# 34          Uno Card Game                 2710
# 19   Mini Basketball Hoop                 2647

# %%
# Visualize Bottom 10 Least selling Products based on  Quantity Sold

import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for the plot
sns.set_style('ticks')

# Create a figure with a specific size
plt.figure(figsize=(10, 8))

# Create a horizontal bar plot
ax = sns.barplot(
    data=least_selling_products,
    y='Product_Name',
    x='Total_Quantity_Sold',  # Use the column directly, sorting is done outside
    orient='h',
    color='gray',
    edgecolor='black',
    width=0.7
)

# Add data labels to each bar
for bar in ax.patches:
    width = bar.get_width()
    ax.text(
        width + 50,  # Add a small offset to the right of the bar
        bar.get_y() + bar.get_height() / 2,  # Center vertically on the bar
        f'{int(width):,}',  # Format with commas, no decimals
        ha='left',  # Horizontal alignment: left
        va='center',  # Vertical alignment: center
        fontweight='bold',  # Bold text
    )

# Add a title to the plot
plt.title("Bottom 10 Least Selling Products", fontsize=16, fontweight='bold')

# Label the x-axis and y-axis with bold font
plt.xlabel("Total Quantity Sold", fontsize=14, fontweight='bold')
plt.ylabel("Product Name", fontsize=14, fontweight='bold')

# Make the x-axis and y-axis tick labels bold
plt.xticks(fontweight='bold')  # Bold x-axis tick labels
plt.yticks(fontweight='bold')  # Bold y-axis tick labels

# Adjust layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %%
# How do sales vary by month, quarter, and year?

# Calculating  First 2022 Monthly Sales Revneue Trends

# Merge the 'product_sales' DataFrame with the 'date_table' DataFrame on the 'Date' column using an inner join.
# This combines sales data with date information (e.g., month, year) for each sale.
month_wise_sales = product_sales.merge(date_table, how='inner', on='Date')

# Calculate the sales revenue for each sale by multiplying the product price by the number of units sold.
# This creates a new column called 'Sales_Revenue' in the DataFrame.
month_wise_sales['Sales_Revenue'] = (month_wise_sales['Product_Price'] * month_wise_sales['Units'])

# Filter the data to include only sales from the year 2022, then group by 'Month_Number' and 'Month_Name'.
# Calculate the total sales revenue for each month in 2022.
month_wise_sales_revenue_2022 = month_wise_sales[month_wise_sales['Year'] == 2022].groupby(['Month_Number', 'Month_Name'])['Sales_Revenue'].sum().reset_index()

# Rename the columns in the resulting DataFrame for clarity.
# The columns are renamed to 'Month_Number', 'Month_Name', and 'Total_Sales_Revenue'.
month_wise_sales_revenue_2022.columns = ['Month_Number', 'Month_Name', 'Total_Sales_Revenue']

# Sort the DataFrame by 'Month_Number' to ensure the months are in chronological order.
month_wise_sales_revenue_2022.sort_values(by='Month_Number')
# Out:
#     Month_Number Month_Name  Total_Sales_Revenue
# 0              1    January            542554.91
# 1              2   February            541351.65
# 2              3      March            589485.19
# 3              4      April            681072.98
# 4              5        May            672369.90
# 5              6       June            661980.22
# 6              7       July            556034.23
# 7              8     August            489422.73
# 8              9  September            585844.04
# 9             10    October            623874.39
# 10            11   November            661304.15
# 11            12   December            877203.69

# %%
# Calculating 2023 Monthly Sales Revenue Trends

# Filter the 'month_wise_sales' DataFrame to include only sales from the year 2023.
# Then, group the filtered data by 'Month_Number' and 'Month_Name'.
# Calculate the total sales revenue for each month in 2023.
month_wise_sales_revenue_2023 = month_wise_sales[month_wise_sales['Year'] == 2023].groupby(['Month_Number', 'Month_Name'])['Sales_Revenue'].sum().reset_index()

# Rename the columns in the resulting DataFrame for clarity.
# The columns are renamed to 'Month_Number', 'Month_Name', and 'Total_Sales_Revenue'.
month_wise_sales_revenue_2023.columns = ['Month_Number', 'Month_Name', 'Total_Sales_Revenue']

# Sort the DataFrame by 'Month_Number' to ensure the months are in chronological order.
month_wise_sales_revenue_2023.sort_values(by='Month_Number')
# Out:
#    Month_Number Month_Name  Total_Sales_Revenue
# 0             1    January            690182.57
# 1             2   February            634791.89
# 2             3      March            776608.68
# 3             4      April            767116.07
# 4             5        May            734863.26
# 5             6       June            737350.16
# 6             7       July            762669.99
# 7             8     August            580370.46
# 8             9  September            612006.83

# %%
# Visualize Yearly Basis Monthly sales ternd 
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('ticks')

plt.figure(figsize=(14, 8))  # Adjusted for better aspect ratio

# Plot 2022 trend
ax = sns.lineplot(
    data=month_wise_sales_revenue_2022,
    x='Month_Name', y='Total_Sales_Revenue',
    linewidth=2.5,  # Thicker line
    color='#FF6B6B',  # Modern coral
    marker='o', markersize=8,  # Larger markers
    linestyle='--',
    label='monthly_sales_revenue_2022'
)

# Plot 2023 trend
sns.lineplot(
    data=month_wise_sales_revenue_2023,
    x='Month_Name', y='Total_Sales_Revenue',
    linewidth=2.5,  # Thicker line
    color='#4ECDC4',  # Modern teal
    marker='o', markersize=8,  # Larger markers
    linestyle='-',
    label='monthly_sales_revenue_2023'
)

# Add data labels for 2022
for i, row in month_wise_sales_revenue_2022.iterrows():
    plt.text(
        row['Month_Name'], 
        row['Total_Sales_Revenue'] + 5000,  # Offset above the point
        f'${row["Total_Sales_Revenue"]:,.0f}',  # Format with dollar sign and commas
        ha='center',  # Horizontal alignment: center
        va='bottom',  # Vertical alignment: bottom
        fontsize=9, 
        fontweight='bold', 
        color='black'  # Changed to black
    )

# Add data labels for 2023
for i, row in month_wise_sales_revenue_2023.iterrows():
    plt.text(
        row['Month_Name'], 
        row["Total_Sales_Revenue"] + 5000,  # Offset above the point
        f'${row["Total_Sales_Revenue"]:,.0f}',  # Format with dollar sign and commas
        ha='center',  # Horizontal alignment: center
        va='bottom',  # Vertical alignment: bottom
        fontsize=9, 
        fontweight='bold', 
        color='black'  # Changed to black
    )

plt.title("Monthly Sales Revenue Trend (2022 vs 2023)", fontsize=16, fontweight='bold', pad=20)
plt.xlabel("Month", fontsize=12, fontweight='bold', labelpad=10)
plt.ylabel("Revenue (USD)", fontsize=12, fontweight='bold', labelpad=10)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', frameon=True)  # Cleaner legend positioning

# Bold and rotate x-ticks
plt.xticks(fontweight='bold', rotation=45, ha='right')
plt.yticks(fontweight='bold')

# Add grid and format y-axis
plt.grid(True, alpha=0.3)
plt.tick_params(axis='both', which='major', labelsize=10)
plt.tight_layout()
plt.show()

# %%
#  Year basis Quarterly Sales Revenue

quarter_wise_sales_revenue_2022 = month_wise_sales[month_wise_sales['Year'] == 2022].groupby("Quarter")['Sales_Revenue'].sum().reset_index()

quarter_wise_sales_revenue_2022.columns = ['Quarter' , 'Total_Sales_Revenue']  

quarter_wise_sales_revenue_2022
# Out:
#   Quarter  Total_Sales_Revenue
# 0   Qtr-1           1673391.75
# 1   Qtr-2           2015423.10
# 2   Qtr-3           1631301.00
# 3   Qtr-4           2162382.23

# %%
quarter_wise_sales_revenue_2023 = month_wise_sales[month_wise_sales['Year'] == 2023].groupby("Quarter")['Sales_Revenue'].sum().reset_index()

quarter_wise_sales_revenue_2023.columns = ['Quarter' , 'Total_Sales_Revenue']  

quarter_wise_sales_revenue_2023
# Out:
#   Quarter  Total_Sales_Revenue
# 0   Qtr-1           2101583.14
# 1   Qtr-2           2239329.49
# 2   Qtr-3           1955047.28

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

plt.figure(figsize=(12, 8))

# Plot 2022 trend
sns.lineplot(
    data=quarter_wise_sales_revenue_2022,
    x='Quarter',
    y='Total_Sales_Revenue',
    linewidth=1,
    color='red',
    marker='o',
    linestyle='--',
    label='Quarterly Sales Revenue 2022'
)

# Plot 2023 trend
sns.lineplot(
    data=quarter_wise_sales_revenue_2023,
    x='Quarter',
    y='Total_Sales_Revenue',
    linewidth=1,
    color='g',
    marker='o',
    linestyle='-',
    label='Quarterly Sales Revenue 2023'
)

# Add data labels for 2022
for i, row in quarter_wise_sales_revenue_2022.iterrows():
    plt.text(
        row['Quarter'], 
        row['Total_Sales_Revenue'] + 5000,  # Offset above the point
        f'${row["Total_Sales_Revenue"]:,.0f}',  # Format with dollar sign and commas
        ha='center',  # Horizontal alignment: center
        va='bottom',  # Vertical alignment: bottom
        fontsize=10, 
        fontweight='bold', 
        color='red'  # Match line color
    )

# Add data labels for 2023
for i, row in quarter_wise_sales_revenue_2023.iterrows():
    plt.text(
        row['Quarter'], 
        row['Total_Sales_Revenue'] + 5000,  # Offset above the point
        f'${row["Total_Sales_Revenue"]:,.0f}',  # Format with dollar sign and commas
        ha='center',  # Horizontal alignment: center
        va='bottom',  # Vertical alignment: bottom
        fontsize=10, 
        fontweight='bold', 
        color='g'  # Match line color
    )

plt.title("Quarterly Sales Revenue Trend of Year Basis", fontsize=16, fontweight='bold')
plt.xlabel("Quarter Name", fontsize=14, fontweight='bold')
plt.ylabel("Total Sales Revenue", fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.09, 1), loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Identify Popular Products Category based on quantity Sold

category_wise_quantity_sold = product_sales.groupby('Product_Category')['Units'].sum().reset_index()

category_wise_quantity_sold.columns = ['Product_Category','Total_unit_sold']

category_wise_quantity_sold.sort_values(by = 'Total_unit_sold' , ascending = False)
# Out:
#     Product_Category  Total_unit_sold
# 0       Art & Crafts           325574
# 4               Toys           267200
# 2              Games           194673
# 3  Sports & Outdoors           169043
# 1        Electronics           134075

# %%
# Visualize Product Category Wise Quantity Sold

import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

# Create pie chart with improved styling
plt.pie(x=category_wise_quantity_sold['Total_unit_sold'],
        explode=[0.05]*len(category_wise_quantity_sold),  # Subtler explosion
        labels=category_wise_quantity_sold['Product_Category'],
        colors=['#4C72B0','#55A868','#C44E52','#8172B2','#CCB974'],  # Modern color palette
        wedgeprops={'edgecolor':'black','linewidth':1},  # Define edges
        autopct='%1.1f%%',
        pctdistance=0.75,
        labeldistance=1.05,
        textprops={'fontsize':12, 'fontweight':'bold'},  # Bolder text
        shadow={'ox':-0.04, 'edgecolor':'gray'},  # Enhanced shadow
        startangle=110)  # Better orientation

plt.legend(bbox_to_anchor=(1.3, 1), loc='upper right', 
          frameon=True, shadow=True)  # Improved legend

plt.title("Product Category Sales Distribution",  # More concise title
         fontsize=16, fontweight='bold', pad=20)  # Added padding

plt.show()

# %%
# Findout Yearly Sales Revenue and Profit trend

sales_revenue_2022 = sum(product_sales[product_sales['Date'] <= '2022-12-31']['Sales_Revenue'])

profit_2022 = sum(product_sales[product_sales['Date'] <= '2022-12-31']['Profit'])

sales_revenue_2023 = sum(product_sales[product_sales['Date'] >= '2023-01-01']['Sales_Revenue'])

profit_2023 = sum(product_sales[product_sales['Date'] >= '2023-01-01']['Profit'])

# %%
# Visualize Yearly ( 2022 & 2023) Sales Revenue and Profit Trends

import matplotlib.pyplot as plt

import numpy as np

import seaborn as sns

# Set style
sns.set_style('ticks')

plt.figure(figsize=(14, 10))


# Data for plotting
years = ['2022', '2023']
revenue = [sales_revenue_2022, sales_revenue_2023]
profit = [profit_2022, profit_2023]

# Set the positions of the bars
bar_width = 0.40
r1 = np.arange(len(years))
r2 = [x + bar_width for x in r1]

# Create bars
plt.bar(r1, revenue, color='#1E90FF', width=bar_width, edgecolor='black', 
        linewidth=1.5, label='Sales Revenue', alpha=0.9)
plt.bar(r2, profit, color='#32CD32', width=bar_width, edgecolor='black', 
        linewidth=1.5, label='Profit', alpha=0.9)

# Customize axes
plt.xlabel('Year', fontsize=16, fontweight='bold', color='#333333')
plt.ylabel('Amount ($)', fontsize=16, fontweight='bold', color='#333333')
plt.title('Yearly Sales Revenue & Profit Comparison (2022-2023)',
         fontsize=20, fontweight='bold', color='#2F4F4F', pad=20)

# Customize ticks
plt.xticks([r + bar_width/2 for r in range(len(years))], years,
          fontsize=12, fontweight='bold', color='#333333')
plt.yticks(fontsize=12, fontweight='bold', color='#333333')

# Add value labels
for i, v in enumerate(revenue):
    plt.text(r1[i], v, f'${v:,.0f}', 
            ha='center', va='bottom', 
            fontweight='bold', fontsize=12, color='#1E90FF')

for i, v in enumerate(profit):
    plt.text(r2[i], v, f'${v:,.0f}', 
            ha='center', va='bottom', 
            fontweight='bold', fontsize=12, color='#32CD32')

# Enhance legend
plt.legend(title='Metric',
          title_fontsize=13,
          fontsize=12,
          frameon=True,
          facecolor='white',
          edgecolor='black',
          loc='upper left',
          bbox_to_anchor=(1.05, 0.98))

# Add grid
plt.grid(True, linestyle='--', alpha=0.9)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# # 2. Inventory Management Analysis Section:-

# %%
#  Which products are overstocked or understocked in each store? 

# Define thresholds
# For example, let's assume:
# - Understocked: Stock_On_Hand < 5
# - Overstocked: Stock_On_Hand > 50

understock_threshold = 5
overstock_threshold = 50

inventory['Understocked'] = inventory['Stock_On_Hand'] < understock_threshold

inventory['Overstocked'] = inventory['Stock_On_Hand'] > overstock_threshold

store_inventory = stores.merge(inventory , how = 'inner',on = 'Store_ID')

store_product_inventory = store_inventory.merge(products , how = 'inner',on = 'Product_ID')

store_wise_understocked_products = store_product_inventory[store_product_inventory['Understocked']][['Store_Name' , 'Product_Name','Stock_On_Hand']]

store_wise_understocked_products.sort_values(by = ['Store_Name' , 'Product_Name'])
# Out:
#                        Store_Name        Product_Name  Stock_On_Hand
# 163   Maven Toys Aguascalientes 1    Chutes & Ladders              1
# 188   Maven Toys Aguascalientes 1    Classic Dominoes              4
# 523   Maven Toys Aguascalientes 1  Foam Disk Launcher              0
# 671   Maven Toys Aguascalientes 1   Hot Wheels 5-Pack              0
# 711   Maven Toys Aguascalientes 1               Jenga              3
# ...                           ...                 ...            ...
# 469        Maven Toys Zacatecas 1       Etch A Sketch              3
# 519        Maven Toys Zacatecas 1  Foam Disk Launcher              4
# 843        Maven Toys Zacatecas 1          Magic Sand              2
# 917        Maven Toys Zacatecas 1  Mini Ping Pong Set              0
# 1239       Maven Toys Zacatecas 1            Playfoam              3
#
# [299 rows x 3 columns]

# %%
store_wise_overstocked_products = store_product_inventory[store_product_inventory['Overstocked']][['Store_Name','Product_Name','Stock_On_Hand']]

store_wise_overstocked_products.sort_values(by = ['Store_Name' , 'Product_Name'])
# Out:
#                        Store_Name      Product_Name  Stock_On_Hand
# 324   Maven Toys Aguascalientes 1     Deck Of Cards             53
# 847   Maven Toys Aguascalientes 1        Magic Sand             67
# 310         Maven Toys Campeche 1     Deck Of Cards             73
# 409         Maven Toys Campeche 1  Dinosaur Figures             57
# 833         Maven Toys Campeche 1        Magic Sand             57
# ...                           ...               ...            ...
# 1104    Maven Toys Villahermosa 1       PlayDoh Can            131
# 1351    Maven Toys Villahermosa 1      Rubik's Cube             53
# 339           Maven Toys Xalapa 2     Deck Of Cards             90
# 1059          Maven Toys Xalapa 2          Nerf Gun             58
# 1090       Maven Toys Zacatecas 1       PlayDoh Can             92
#
# [118 rows x 3 columns]

# %%
# What is the inventory turnover rate for each product category?

# %% [markdown]
# # Inventory Turnover Rate= (Cost of Goods Sold (COGS) / Average Inventory)
#
# # Cost of Goods Sold (COGS) = Multiply the number of units sold (Unit_sold from the sales table) by the product cost (Product_Cost from the products table) for each product category.
#
# # Average Inventory = Compute the average Stock_On_Hand for each product category using the inventory table.

# %%
# Merge sales and products to get product cost
sales_with_cost = pd.merge(sales, products, on='Product_ID', how='left')

# Calculate COGS for each sale
sales_with_cost['COGS'] = sales_with_cost['Product_Cost'] * sales_with_cost['Units']

# Sum COGS by product category
total_cogs = sales_with_cost.groupby('Product_Category')['COGS'].sum().reset_index()
total_cogs.columns = ['Product_Category', 'Total_COGS']

# Merge inventory and products to get product category
inventory_with_category = pd.merge(inventory, products, how='inner', on='Product_ID')

# Calculate average inventory for each product category
average_inventory = inventory_with_category.groupby('Product_Category')['Stock_On_Hand'].mean().reset_index()
average_inventory.columns = ['Product_Category', 'Average_inventory']

# Merge total COGS and average inventory
turnover_rate = pd.merge(total_cogs, average_inventory, how='inner', on='Product_Category')

# Calculate inventory turnover rate
turnover_rate['Inventory_Turnover_Rate'] = round(turnover_rate['Total_COGS'] / turnover_rate['Average_inventory'] , 1)

# Display the result
turnover_rate[['Product_Category', 'Inventory_Turnover_Rate']]
# Out:
#     Product_Category  Inventory_Turnover_Rate
# 0       Art & Crafts                  89745.0
# 1        Electronics                  76739.0
# 2              Games                  69884.3
# 3  Sports & Outdoors                 108075.7
# 4               Toys                 237538.7

# %%
# Visualize Product Category Wise Turnover rate

import matplotlib.pyplot as plt
import numpy as np

# Create donut chart
plt.figure(figsize=(10, 8))

# Data for the chart (assuming turnover_rate exists from previous code)
labels = turnover_rate['Product_Category']
sizes = turnover_rate['Inventory_Turnover_Rate']

# Colors for each segment
colors = plt.cm.Set3(np.linspace(0, 1, len(labels)))

# Create pie chart with a hole in the center
wedges, texts = plt.pie(sizes, 
                        colors=colors, 
                        startangle=90, 
                        wedgeprops=dict(width=0.3, edgecolor='white'))

# Calculate percentages manually
total = sum(sizes)
percentages = [f'{(size/total)*100:.1f}%' for size in sizes]

# Add legend with percentages
plt.legend(wedges, 
          [f'{label}: {pct}' for label, pct in zip(labels, percentages)],
          title='Product Category (Turnover Rate)',
          title_fontsize=13,
          fontsize=12,
          loc='center left',
          bbox_to_anchor=(1, 0, 0.5, 1),
          frameon=True,
          edgecolor='black')

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Add title
plt.title('Inventory Turnover Rate by Product Category',
         fontsize=16,
         fontweight='bold',
         color='#2F4F4F',
         pad=20)

# Add a circle at the center to create the donut effect
centre_circle = plt.Circle((0, 0), 0.50, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Display the chart
plt.tight_layout()
plt.show()

# %%
# Are there any products that are consistently out of stock, leading to potential lost sales? 

product_sold = product_sales.groupby(['Product_ID','Product_Name'])['Units'].sum().reset_index()

product_sold.columns = ['Product_ID','Product_Name' , 'Total_Units_Sold']

product_stock = inventory.groupby('Product_ID')['Stock_On_Hand'].mean().reset_index()

product_stock.columns = ['Product_ID','Average_Stock']

product_stock['Average_Stock'] = round(product_stock['Average_Stock'] , 0)

merge_df = pd.merge(product_sold , product_stock , how = 'inner' , on = 'Product_ID')

merge_df[merge_df['Average_Stock'] < 5].sort_values(by = 'Total_Units_Sold' , ascending = False)
# Out:
# Empty DataFrame
# Columns: [Product_ID, Product_Name, Total_Units_Sold, Average_Stock]
# Index: []

# %%
# How does the stock-on-hand level correlate with sales performance? 

correlation = merge_df['Total_Units_Sold'].corr(merge_df['Average_Stock'])

print("Hence Required correlation Between Stock_On_Hand and Products Sales/Units Sold is : ",round(correlation , 1))
# Out:
# Hence Required correlation Between Stock_On_Hand and Products Sales/Units Sold is :  0.7

# %%
# Which stores have the best and worst inventory management practices? 
store_wise_product_sold = sales.groupby('Store_ID')['Units'].sum().reset_index()

store_wise_product_sold.columns = ['Store_ID' , 'Total_Units_Sold']

store_wise_inventory = inventory.groupby('Store_ID')['Stock_On_Hand'].sum().reset_index()

store_wise_inventory.columns = ['Store_ID','Total_Stock']

store_metrics = pd.merge(store_wise_product_sold,store_wise_inventory , how = 'inner',on ='Store_ID')

store_metrics = pd.merge(store_metrics , stores , how = 'inner' , on = 'Store_ID')

store_metrics['Inventory_Turnover_Ratio'] = round(store_metrics['Total_Units_Sold'] / store_metrics['Total_Stock'] , 0)

stockout_frequency = inventory[inventory['Stock_On_Hand'] == 0].groupby('Store_ID').size().reset_index()

stockout_frequency.columns = ['Store_ID','Stockout_Frequency']

store_metrics = pd.merge(store_metrics , stockout_frequency, how = 'inner' , on = 'Store_ID')

# Best stores: High turnover, low stockout frequency

store_metrics['Rank'] = store_metrics['Inventory_Turnover_Ratio'].rank(ascending=False) + store_metrics['Stockout_Frequency'].rank(ascending=True)

store_metrics[['Store_Name' , 'Total_Units_Sold' , 'Total_Stock','Inventory_Turnover_Ratio','Stockout_Frequency','Rank']].sort_values(by = 'Rank')
# Out:
#                        Store_Name  Total_Units_Sold  Total_Stock  \
# 3           Maven Toys Saltillo 1             24010          437
# 19            Maven Toys Oaxaca 1             18564          479
# 18   Maven Toys Ciudad Victoria 1             20501          546
# 20            Maven Toys Puebla 2             22413          420
# 6          Maven Toys Monterrey 2             28318          558
# 15         Maven Toys Zacatecas 1             17196          480
# 26  Maven Toys Ciudad de Mexico 3             26634          636
# 33  Maven Toys Ciudad de Mexico 4             22729          551
# 22         Maven Toys Monterrey 3             22076          539
# 10        Maven Toys Guanajuato 1             24740          367
# 5           Maven Toys Mexicali 1             22858          679
# 12   Maven Toys San Luis Potosi 1             19635          582
# 29            Maven Toys Toluca 2             15964          472
# ...

# %%
print("Best Performance Stores are: ")
store_metrics[['Store_Name' , 
               'Total_Units_Sold' ,
               'Total_Stock',
               'Inventory_Turnover_Ratio',
               'Stockout_Frequency',
               'Rank']].sort_values(by = 'Rank').head(5)
# Out:
# Best Performance Stores are:
#                       Store_Name  Total_Units_Sold  Total_Stock  \
# 3          Maven Toys Saltillo 1             24010          437
# 19           Maven Toys Oaxaca 1             18564          479
# 18  Maven Toys Ciudad Victoria 1             20501          546
# 20           Maven Toys Puebla 2             22413          420
# 6         Maven Toys Monterrey 2             28318          558
#
#     Inventory_Turnover_Ratio  Stockout_Frequency  Rank
# 3                       55.0                   1  10.5
# 19                      39.0                   1  22.0
# 18                      38.0                   1  23.5
# 20                      53.0                   2  24.0
# 6                       51.0                   2  25.0

# %%
print("Low Performance Stores are: ")

store_metrics[['Store_Name' , 
               'Total_Units_Sold' ,
               'Total_Stock',
               'Inventory_Turnover_Ratio',
               'Stockout_Frequency',
               'Rank']].sort_values(by = 'Rank').tail(5)
# Out:
# Low Performance Stores are:
#                      Store_Name  Total_Units_Sold  Total_Stock  \
# 7          Maven Toys Pachuca 1             19185          548
# 35        Maven Toys Culiacan 1             19909          738
# 4           Maven Toys La Paz 1             16217          473
# 30      Maven Toys Hermosillo 2             23498          725
# 17  Maven Toys Aguascalientes 1             17865          654
#
#     Inventory_Turnover_Ratio  Stockout_Frequency  Rank
# 7                       35.0                   4  53.0
# 35                      27.0                   2  54.5
# 4                       34.0                   5  58.5
# 30                      32.0                   4  59.0
# 17                      27.0                   4  67.5

# %% [markdown]
# # 3. Product Profitability Analysis Section:-

# %%
#  Which product categories contribute the most to overall profitability? 

product_sales['Profit'] = (product_sales['Product_Price'] - product_sales['Product_Cost'])* product_sales['Units']

product_category_wise_profit = product_sales.groupby('Product_Category')['Profit'].sum().reset_index()

product_category_wise_profit.columns = ['Product_Category','Total_Profit']

product_category_wise_profit['Overall_profit(%)'] = round((product_category_wise_profit['Total_Profit']*100)/sum(product_sales['Profit']) , 1)

product_category_wise_profit.sort_values(by ='Total_Profit' , ascending = False)
# Out:
#     Product_Category  Total_Profit  Overall_profit(%)
# 4               Toys     1079527.0               26.9
# 1        Electronics     1001437.0               24.9
# 0       Art & Crafts      753354.0               18.8
# 2              Games      673993.0               16.8
# 3  Sports & Outdoors      505718.0               12.6

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Prepare data for heatmap
# Pivot the table to have Product_Category as index and metrics as columns
heatmap_data = product_category_wise_profit.set_index('Product_Category')[['Total_Profit',
                                                                           'Overall_profit(%)']].sort_values(by ='Total_Profit', 
                                                                                                             ascending = False)

# Create the heatmap
plt.figure(figsize=(10, 8))

# Use seaborn heatmap
sns.heatmap(heatmap_data, 
            annot=True,  # Show values in cells
            fmt='.1f',   # Format for Overall_profit(%)
            cmap='YlOrRd',  # Yellow-Orange-Red color scheme
            cbar_kws={'label': 'Value Magnitude'},  # Colorbar label
            linewidths=0.5,  # Line between cells
            linecolor='gray')  # Line color

# Customize the plot
plt.title('Profit Analysis by Product Category',
         fontsize=16,
         fontweight='bold',
         color='#2F4F4F',
         pad=20)

plt.xlabel('Metrics',
         fontsize=14,
         fontweight='bold',
         color='#333333')

plt.ylabel('Product Category',
         fontsize=14,
         fontweight='bold',
         color='#333333')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45, ha='right', fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
#  Which products have the highest and lowest profit margins?

product_profit = product_sales.groupby(['Product_ID' , 'Product_Name'])['Profit'].sum().reset_index()

product_profit.columns = ['Product_ID' , 'Product_Name' , 'Total_Profit']

product_profit.sort_values(by = 'Total_Profit' , ascending = False)
# Out:
#     Product_ID           Product_Name  Total_Profit
# 5            6              Colorbuds      834944.0
# 0            1          Action Figure      347748.0
# 17          18            Lego Bricks      298685.0
# 7            8          Deck Of Cards      252102.0
# 13          14          Glass Marbles      187590.0
# 2            3        Barrel O' Slime      183326.0
# 16          17        Kids Makeup Kit      146598.0
# 23          24               Nerf Gun      132715.0
# 6            7               Dart Gun      126352.0
# 10          11          Etch A Sketch      121680.0
# 18          19             Magic Sand      121196.0
# 1            2         Animal Figures      117267.0
# 9           10       Dinosaur Figures      116048.0
# 12          13       Gamer Headphones      107748.0
# 24          25            PlayDoh Can      103128.0
# 20          21     Mini Ping Pong Set      100812.0
# 15          16                  Jenga       91378.0
# ...

# %%
print("Highest Profit Margin or Highest Profitable Products are : ")

product_profit.sort_values(by = 'Total_Profit' , ascending = False).head(5)
# Out:
# Highest Profit Margin or Highest Profitable Products are :
#     Product_ID   Product_Name  Total_Profit
# 5            6      Colorbuds      834944.0
# 0            1  Action Figure      347748.0
# 17          18    Lego Bricks      298685.0
# 7            8  Deck Of Cards      252102.0
# 13          14  Glass Marbles      187590.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

top_5_profit = product_profit.sort_values(by='Total_Profit', ascending=False).head(5)

# Create the column chart
plt.figure(figsize=(12, 8))

# Use seaborn for styling
sns.set_style('whitegrid')

# Create bar plot
bars = plt.bar(top_5_profit['Product_Name'], 
               top_5_profit['Total_Profit'],
               color='#1E90FF',  # Vibrant blue
               edgecolor='black',
               linewidth=1.5,
               alpha=0.9)

# Customize the plot
plt.title('Top 5 Products Name by Total Profit',
         fontsize=16,
         fontweight='bold',
         color='#2F4F4F',
         pad=20)

plt.xlabel('Product Name',
          fontsize=14,
          fontweight='bold',
          color='#333333')

plt.ylabel('Total Profit ($)',
          fontsize=14,
          fontweight='bold',
          color='#333333')

# Customize ticks
plt.xticks(rotation=45, ha='right', fontsize=12, fontweight='bold', color='#333333')
plt.yticks(fontsize=12, fontweight='bold', color='#333333')

# Add value labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
            f'${height:,.0f}',
            ha='center',
            va='bottom',
            fontweight='bold',
            fontsize=12,
            color='#1E90FF')

# Add grid for readability
plt.grid(True, linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
print("Lowest Profit Margin or Lowest Profitable Products are: ")

product_profit.sort_values(by = 'Total_Profit' , ascending = True).head(5)
# Out:
# Lowest Profit Margin or Lowest Profitable Products are:
#     Product_ID      Product_Name  Total_Profit
# 4            5  Classic Dominoes        8942.0
# 34          35     Uno Card Game       10840.0
# 3            4  Chutes & Ladders       11487.0
# 32          33        Teddy Bear       12832.0
# 21          22          Monopoly       20310.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

least_5_profit = product_profit.sort_values(by='Total_Profit', ascending= False).tail(5)

# Create the column chart
plt.figure(figsize=(12, 8))

# Use seaborn for styling
sns.set_style('whitegrid')

# Create bar plot
bars = plt.bar(least_5_profit['Product_Name'], 
               least_5_profit['Total_Profit'],
               color='#1E90FF',  # Vibrant blue
               edgecolor='black',
               linewidth=1.5,
               alpha=0.9)

# Customize the plot
plt.title('Bottom 5 Products Name by Total Profit',
         fontsize=16,
         fontweight='bold',
         color='#2F4F4F',
         pad=20)

plt.xlabel('Product Name',
          fontsize=14,
          fontweight='bold',
          color='#333333')

plt.ylabel('Total Profit ($)',
          fontsize=14,
          fontweight='bold',
          color='#333333')

# Customize ticks
plt.xticks(rotation=45, ha='right', fontsize=12, fontweight='bold', color='#333333')
plt.yticks(fontsize=12, fontweight='bold', color='#333333')

# Add value labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
            f'${height:,.0f}',
            ha='center',
            va='bottom',
            fontweight='bold',
            fontsize=12,
            color='#1E90FF')

# Add grid for readability
plt.grid(True, linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Are there any products that are sold at a loss (i.e., selling price is less than cost)? 

print("Products With selling Price is less than Cost Price: ")

products[products['Product_Price'] < products['Product_Cost']]
# Out:
# Products With selling Price is less than Cost Price:
# Empty DataFrame
# Columns: [Product_ID, Product_Name, Product_Category, Product_Cost, Product_Price]
# Index: []

# %% [markdown]
# # 4. Geographical Analysis Section :-

# %%
# How do sales and inventory levels vary across different cities and store locations? 

# Firstly Findout Sales and Inventory levels across different store cities.

store_product_sales = pd.merge(store_sales , products , how = 'inner' , on ='Product_ID')

store_product_sales['Sales_Revenue'] = store_product_sales['Product_Price']* store_product_sales['Units']

store_city_wise_sales_revenue = store_product_sales.groupby('Store_City')['Sales_Revenue'].sum().reset_index()

store_city_wise_sales_revenue.columns = ['Store_City' , 'Total_Sales_Revenue(US Dollar $)']

store_city_wise_sales_revenue.sort_values(by = 'Total_Sales_Revenue(US Dollar $)' , ascending = False)
# Out:
#           Store_City  Total_Sales_Revenue(US Dollar $)
# 7   Cuidad de Mexico                        1649492.01
# 10       Guadalajara                        1322099.46
# 16         Monterrey                        1261845.70
# 12        Hermosillo                         903388.84
# 11        Guanajuato                         869055.83
# 20            Puebla                         808710.29
# 24            Toluca                         633521.68
# 27            Xalapa                         610119.77
# 15          Mexicali                         586175.85
# 21          Saltillo                         579514.97
# 1           Campeche                         517841.67
# 3          Chihuahua                         516713.04
# 5    Ciudad Victoria                         294803.99
# 23          Santiago                         277598.14
# 17           Morelia                         273060.05
# 22   San Luis Potosi                         263389.65
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sort by Total_Sales_Revenue and get top 10
top_10_sales = store_city_wise_sales_revenue.sort_values(by='Total_Sales_Revenue(US Dollar $)', ascending=False).head(10)

# Create the horizontal bar chart
plt.figure(figsize=(14, 10))

# Use seaborn for styling
sns.set_style('whitegrid')

# Create horizontal bar plot
bars = plt.barh(top_10_sales['Store_City'], 
                 top_10_sales['Total_Sales_Revenue(US Dollar $)'],
                 color='#1E90FF',  # Vibrant blue
                 edgecolor='black',
                 linewidth=1.5,
                 alpha=0.9)

# Customize the plot
plt.title('Top 10 Store Cities by Total Sales Revenue',
         fontsize=16,
         fontweight='bold',
         color='#2F4F4F',
         pad=20)

plt.xlabel('Total Sales Revenue (US Dollar $)',
          fontsize=14,
          fontweight='bold',
          color='#333333')

plt.ylabel('Store City',
          fontsize=14,
          fontweight='bold',
          color='#333333')

# Customize ticks
plt.xticks(fontsize=12, fontweight='bold', color='#333333')
plt.yticks(fontsize=12, fontweight='bold', color='#333333')

# Add value labels to the right of each bar
for bar in bars:
    width = bar.get_width()
    plt.text(x=width + max(top_10_sales['Total_Sales_Revenue(US Dollar $)']) * 0.01,  # Use keyword x=
             y=bar.get_y() + bar.get_height()/2.,
             s=f'${width:,.0f}',
             ha='left',  # Align text to the left of the bar end
             va='center',
             fontweight='bold',
             fontsize=12,
             color='#1E90FF')

# Add grid for readability
plt.grid(True, linestyle='--', alpha=0.7, axis='x')  # Grid only on x-axis

# Invert y-axis to have highest revenue at the top
plt.gca().invert_yaxis()

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Secondly Findout Sales and Inventory levels across different store Locations.

store_location_wise_sales_revenue = store_product_sales.groupby("Store_Location")['Sales_Revenue'].sum().reset_index()

store_location_wise_sales_revenue.columns = ['Store_Location' , 'Total_Sales_Revenue(US Dollar $)']

store_location_wise_sales_revenue['Overall_Sales_Revenue(%)'] =round((store_location_wise_sales_revenue['Total_Sales_Revenue(US Dollar $)']*100)/ sum(store_location_wise_sales_revenue['Total_Sales_Revenue(US Dollar $)']),1)

store_location_wise_sales_revenue.sort_values(by = 'Total_Sales_Revenue(US Dollar $)' , ascending = False)
# Out:
#   Store_Location  Total_Sales_Revenue(US Dollar $)  Overall_Sales_Revenue(%)
# 2       Downtown                        8219596.27                      56.9
# 1     Commercial                        3279139.52                      22.7
# 3    Residential                        1656113.98                      11.5
# 0        Airport                        1289722.58                       8.9

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

location_wise_sales = store_location_wise_sales_revenue.sort_values(by='Total_Sales_Revenue(US Dollar $)', ascending=False)

# Create the horizontal bar chart
plt.figure(figsize=(14, 10))

# Use seaborn for styling
sns.set_style('whitegrid')

# Create horizontal bar plot
bars = plt.barh(location_wise_sales['Store_Location'], 
                 location_wise_sales['Total_Sales_Revenue(US Dollar $)'],
                 color='#1E90FF',  # Vibrant blue
                 edgecolor='black',
                 linewidth=1.5,
                 alpha=0.9)

# Customize the plot
plt.title(' Store Locations by Total Sales Revenue',
         fontsize=16,
         fontweight='bold',
         color='#2F4F4F',
         pad=20)

plt.xlabel('Total Sales Revenue (US Dollar $)',
          fontsize=14,
          fontweight='bold',
          color='#333333')

plt.ylabel('Store Location',
          fontsize=14,
          fontweight='bold',
          color='#333333')

# Customize ticks
plt.xticks(fontsize=12, fontweight='bold', color='#333333')
plt.yticks(fontsize=12, fontweight='bold', color='#333333')

# Add value labels to the right of each bar (showing both $ and %)
for bar in bars:
    width = bar.get_width()
    index = location_wise_sales.index[location_wise_sales['Total_Sales_Revenue(US Dollar $)'] == width].tolist()[0]
    percentage = location_wise_sales.loc[index, 'Overall_Sales_Revenue(%)']
    plt.text(x=width + max(top_10_sales['Total_Sales_Revenue(US Dollar $)']) * 0.01,
             y=bar.get_y() + bar.get_height()/2.,
             s=f'${width:,.0f} ({percentage}%)',
             ha='left',
             va='center',
             fontweight='bold',
             fontsize=12,
             color='#1E90FF')

# Add grid for readability
plt.grid(True, linestyle='--', alpha=0.7, axis='x')  # Grid only on x-axis

# Invert y-axis to have highest revenue at the top
plt.gca().invert_yaxis()

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Are there any regional preferences for specific product categories? 

# Firstly Findout Store city wise product category sales revenue 

regional_category_preferences = store_product_sales.groupby(['Store_City' , 'Product_Category'])['Sales_Revenue'].sum().reset_index()

regional_category_preferences.columns = ['Store_City','Product_Category','Total_Sales_Revenue(US Dollar $)']

regional_category_preferences.sort_values(by =['Store_City','Total_Sales_Revenue(US Dollar $)'],ascending =[True , False])
# Out:
#          Store_City   Product_Category  Total_Sales_Revenue(US Dollar $)
# 4    Aguascalientes               Toys                          86071.53
# 2    Aguascalientes              Games                          44464.80
# 1    Aguascalientes        Electronics                          43525.87
# 3    Aguascalientes  Sports & Outdoors                          33311.20
# 0    Aguascalientes       Art & Crafts                          32623.95
# ..              ...                ...                               ...
# 144       Zacatecas               Toys                          87016.28
# 140       Zacatecas       Art & Crafts                          59771.06
# 143       Zacatecas  Sports & Outdoors                          31727.33
# 142       Zacatecas              Games                          29087.49
# 141       Zacatecas        Electronics                          22380.88
#
# [145 rows x 3 columns]

# %%
# Secondly Findout store Location wise product category sales revenue.

location_catgory_preferences = store_product_sales.groupby(['Store_Location','Product_Category'])['Sales_Revenue'].sum().reset_index()

location_catgory_preferences.columns = ['Store_Location' , 'Product_Category' , 'Total_Sales_Revenue(US Dollar $)']

location_catgory_preferences.sort_values(by = ['Store_Location' , 'Total_Sales_Revenue(US Dollar $)'] , ascending = [True , False])
# Out:
#    Store_Location   Product_Category  Total_Sales_Revenue(US Dollar $)
# 4         Airport               Toys                         415754.96
# 2         Airport              Games                         240004.10
# 1         Airport        Electronics                         236496.53
# 0         Airport       Art & Crafts                         209363.67
# 3         Airport  Sports & Outdoors                         188103.32
# 9      Commercial               Toys                        1081318.82
# 6      Commercial        Electronics                         634885.42
# 5      Commercial       Art & Crafts                         591698.53
# 8      Commercial  Sports & Outdoors                         493071.68
# 7      Commercial              Games                         478165.07
# 14       Downtown               Toys                        2946755.19
# 10       Downtown       Art & Crafts                        1604073.67
# ...

# %%
#  Which city or store location generates the highest revenue and profit? 

# Firstly Findout Store Location wise Profit

store_product_sales['Profit'] = (store_product_sales['Product_Price'] - store_product_sales['Product_Cost'])* store_product_sales['Units']

store_location_wise_profit = store_product_sales.groupby('Store_Location')['Profit'].sum().reset_index()

store_location_wise_profit.columns = ['Store_Location' , 'Total_Profit(US Dollar $)']


store_location_wise_profit.sort_values(by = 'Total_Profit(US Dollar $)' , ascending = False)
# Out:
#   Store_Location  Total_Profit(US Dollar $)
# 2       Downtown                  2248728.0
# 1     Commercial                   926864.0
# 3    Residential                   460388.0
# 0        Airport                   378049.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming store_location_wise_profit is defined; using your sorting
location_wise_profit = store_location_wise_profit.sort_values(by='Total_Profit(US Dollar $)', ascending=False)

# Create the scatter plot
plt.figure(figsize=(12, 8))

# Use seaborn for styling
sns.set_style('whitegrid')

# Create scatter plot with smaller, fixed-size bubbles
scatter = plt.scatter(range(len(location_wise_profit)),  # x-axis as index for spacing
                      location_wise_profit['Total_Profit(US Dollar $)'],
                      s= 1000,  # Fixed small size for all bubbles
                      c='#1E90FF',  # Vibrant blue
                      edgecolors='black',
                      linewidth=1.5,
                      alpha=0.8)

# Customize the plot
plt.title('Store Locations by Total Profit',
         fontsize=16,
         fontweight='bold',
         color='#2F4F4F',
         pad=20)

plt.xlabel('Store Location',
          fontsize=14,
          fontweight='bold',
          color='#333333')

plt.ylabel('Total Profit (US Dollar $)',
          fontsize=14,
          fontweight='bold',
          color='#333333')

# Customize x-ticks with store names
plt.xticks(range(len(location_wise_profit)), 
           location_wise_profit['Store_Location'], 
           rotation=45, 
           ha='right', 
           fontsize=12, 
           fontweight='bold', 
           color='#333333')

plt.yticks(fontsize=12, fontweight='bold', color='#333333')

# Add value labels next to each point
for i, (x, y, label) in enumerate(zip(range(len(location_wise_profit)), 
                                     location_wise_profit['Total_Profit(US Dollar $)'], 
                                     location_wise_profit['Store_Location'])):
    plt.text(x + 0.2, y, f'${y:,.0f}',
             ha='left',
             va='center',
             fontweight='bold',
             fontsize=10,
             color='#1E90FF')

# Add grid for readability
plt.grid(True, linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Secondly Findout Store City wise Profit

store_city_wise_profit = store_product_sales.groupby('Store_City')['Profit'].sum().reset_index()

store_city_wise_profit.columns = ['Store_City' , 'Total_Profit(US Dollar $)']


store_city_wise_profit.sort_values(by = 'Total_Profit(US Dollar $)' , ascending = False)
# Out:
#           Store_City  Total_Profit(US Dollar $)
# 7   Cuidad de Mexico                   465558.0
# 10       Guadalajara                   368930.0
# 16         Monterrey                   346729.0
# 12        Hermosillo                   263608.0
# 11        Guanajuato                   235047.0
# 20            Puebla                   229694.0
# 15          Mexicali                   175048.0
# 27            Xalapa                   163720.0
# 21          Saltillo                   163248.0
# 24            Toluca                   162702.0
# 3          Chihuahua                   146868.0
# 1           Campeche                   146339.0
# 17           Morelia                    90484.0
# 5    Ciudad Victoria                    83088.0
# 26      Villahermosa                    74221.0
# 23          Santiago                    72922.0
# 22   San Luis Potosi                    68880.0
# 0     Aguascalientes                    68642.0
# 2           Chetumal                    67940.0
# ...

# %%
# Visualize Top Stores Cities based on Profit
import matplotlib.pyplot as plt
import numpy as np

# Select the top 10 cities
top_10_cities = store_city_wise_profit.sort_values(by='Total_Profit(US Dollar $)', ascending=False).head(10)

# Use a single vibrant color for all bars
bar_color = '#1f77b4'  # A nice shade of blue (you can change this hex code if desired)

# Create the horizontal bar plot
plt.figure(figsize=(12, 8))  # Larger figure for better visibility
bars = plt.barh(top_10_cities['Store_City'], top_10_cities['Total_Profit(US Dollar $)'], 
                 color=bar_color, edgecolor='black', height=0.7)  # Thicker bars with borders

# Customize the plot
plt.xlabel('Total Profit (US Dollar $)', fontsize=12, weight='bold')
plt.ylabel('Store City', fontsize=12, weight='bold')
plt.title('Top 10 Store Cities by Profit', fontsize=16, weight='bold', pad=20)

# Add value labels on the bars
for bar in bars:
    width = bar.get_width()
    plt.text(width + max(top_10_cities['Total_Profit(US Dollar $)']) * 0.01,  # x-coordinate with offset
             bar.get_y() + bar.get_height()/2,  # y-coordinate
             f'${width:,.2f}',  # Text to display
             va='center', ha='left', fontsize=10, color='black', weight='bold')  # Styling

# Invert y-axis to show highest profit at the top
plt.gca().invert_yaxis()

# Add gridlines for better readability
plt.grid(axis='x', linestyle='--', alpha=0.7, color='gray')

# Adjust layout and style
plt.tight_layout()
plt.style.use('ggplot')  # Use a stylish background theme
plt.show()

# %% [markdown]
# # 5. Customer Demand and Forecasting Analysis Section:-

# %%
# What are the peak sales periods (e.g., holidays, weekends)? 

def findout_week_day_type(week_day):
    if week_day =='Saturday' or week_day =='Sunday':
        return 'Weekends'
    else:
        return 'Weekdays'
    
# Add Another Column week_day_type in the date_table dataframe

date_table['Week_Day_Type'] = date_table['Week_day'].apply(findout_week_day_type)

date_table
# Out:
#           Date Month_Name Quarter   Week_day  Year Week_number  Month_Number  \
# 0   2022-01-01    January   Qtr-1   Saturday  2022      Week-1             1
# 1   2022-01-02    January   Qtr-1     Sunday  2022      Week-2             1
# 2   2022-01-03    January   Qtr-1     Monday  2022      Week-2             1
# 3   2022-01-04    January   Qtr-1    Tuesday  2022      Week-2             1
# 4   2022-01-05    January   Qtr-1  Wednesday  2022      Week-2             1
# ..         ...        ...     ...        ...   ...         ...           ...
# 606 2023-09-26  September   Qtr-3    Tuesday  2023     Week-39             9
# 607 2023-09-27  September   Qtr-3  Wednesday  2023     Week-39             9
# 608 2023-09-28  September   Qtr-3   Thursday  2023     Week-39             9
# 609 2023-09-29  September   Qtr-3     Friday  2023     Week-39             9
# 610 2023-09-30  September   Qtr-3   Saturday  2023     Week-39             9
#
#     Week_Day_Type
# 0        Weekends
# ...

# %%
product_sales['Sales_Revenue'] = product_sales['Product_Price'] * product_sales['Units']


sales_period = pd.merge(product_sales , date_table , how = 'inner' ,on = 'Date')

peak_sales_period = sales_period.groupby('Week_Day_Type')['Sales_Revenue'].sum().reset_index()

peak_sales_period.columns = ['Week_Day_Type','Total_Sales_Revenue(US Dollar $)']

peak_sales_period.sort_values(by = 'Total_Sales_Revenue(US Dollar $)' , ascending = False)
# Out:
#   Week_Day_Type  Total_Sales_Revenue(US Dollar $)
# 0      Weekdays                        9371879.56
# 1      Weekends                        4406578.43

# %%
#  Peak Sales Period Based on Every Single Weekday 

peak_sales_period_weekday = sales_period.groupby('Week_day')['Sales_Revenue'].sum().reset_index()

peak_sales_period_weekday.columns = ['Week_day','Total_Sales_Revenue(US Dollar $)']

peak_sales_period_weekday.sort_values(by = 'Total_Sales_Revenue(US Dollar $)' , ascending = False)
# Out:
#     Week_day  Total_Sales_Revenue(US Dollar $)
# 2   Saturday                        2724995.18
# 0     Friday                        2601006.29
# 4   Thursday                        2107006.50
# 3     Sunday                        1681583.25
# 6  Wednesday                        1639582.90
# 5    Tuesday                        1563831.45
# 1     Monday                        1460452.42

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the correct order of weekdays
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Reorder the DataFrame based on weekday_order
peak_sales_period_weekday['Week_day'] = pd.Categorical(peak_sales_period_weekday['Week_day'], 
                                                       categories=weekday_order, 
                                                       ordered=True)
peak_sales_period_weekday = peak_sales_period_weekday.sort_values('Week_day')

# Create the line chart
plt.figure(figsize=(12, 6))

# Use seaborn for styling
sns.set_style('whitegrid')

# Create line plot
plt.plot(peak_sales_period_weekday['Week_day'], 
         peak_sales_period_weekday['Total_Sales_Revenue(US Dollar $)'],
         marker='o',  # Add markers at data points
         color='#1E90FF',  # Vibrant blue
         linewidth=2.5,
         markersize=10,
         markeredgecolor='black',
         markeredgewidth=1.5)

# Customize the plot
plt.title('Peak Sales Period by Weekday',
         fontsize=16,
         fontweight='bold',
         color='#2F4F4F',
         pad=20)

plt.xlabel('Weekday',
          fontsize=14,
          fontweight='bold',
          color='#333333')

plt.ylabel('Total Sales Revenue (US Dollar $)',
          fontsize=14,
          fontweight='bold',
          color='#333333')

# Customize ticks
plt.xticks(rotation=45, ha='right', fontsize=12, fontweight='bold', color='#333333')
plt.yticks(fontsize=12, fontweight='bold', color='#333333')

# Add value labels above each point
for i, (x, y) in enumerate(zip(peak_sales_period_weekday['Week_day'], 
                              peak_sales_period_weekday['Total_Sales_Revenue(US Dollar $)'])):
    plt.text(x, y + (max(peak_sales_period_weekday['Total_Sales_Revenue(US Dollar $)']) * 0.01),  # Manual offset
             f'${y:,.0f}',
             ha='center',
             va='bottom',
             fontweight='bold',
             fontsize=10,
             color='#1E90FF')

# Add grid for readability
plt.grid(True, linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Can we forecast future sales based on historical data?

from statsmodels.tsa.arima.model import ARIMA

# Fit the ARIMA model
# order=(p, d, q): p=autoregressive, d=differencing, q=moving average
# Here, we use order=(2, 1, 0) as an example. You may need to tune these parameters.

model = ARIMA(month_wise_sales_revenue_2023['Total_Sales_Revenue'] , order = (2 , 1, 0))

model_fit = model.fit()

# Forecast the next 12 months

forecast = model_fit.forecast(steps = 12)

# Create a DataFrame for the forecasted values

forecast_df = pd.DataFrame({'Month_Number':range(10,22),
                           'Forecast_Sales_Revenue':round(forecast,0)})


print("Forecast for Next 12 Months(from 2023 september to 2024 september): ")

forecast_df
# Out:
# Forecast for Next 12 Months(from 2023 september to 2024 september):
#     Month_Number  Forecast_Sales_Revenue
# 9             10                577632.0
# 10            11                585758.0
# 11            12                579115.0
# 12            13                581038.0
# 13            14                579728.0
# 14            15                580164.0
# 15            16                579901.0
# 16            17                579997.0
# 17            18                579944.0
# 18            19                579965.0
# 19            20                579954.0
# 20            21                579958.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for the plot
sns.set_style("whitegrid")  # Use a white grid background
plt.figure(figsize=(12,8))  # Increase the figure size

# Plot historical data
sns.lineplot(data=month_wise_sales_revenue_2023,
             x='Month_Number',
             y='Total_Sales_Revenue',
             linestyle='-',
             marker='o',
             color='#1f77b4',  # A nicer shade of blue
             linewidth=2,
             markersize=8,
             label='Historical Sales Revenue (2023)')

# Plot forecasted data
sns.lineplot(data=forecast_df,
             x='Month_Number',
             y='Forecast_Sales_Revenue',
             linestyle='--',
             marker='x',
             color='#ff7f0e',  # A nicer shade of orange
             linewidth=2,
             markersize=8,
             label='Forecasted Sales Revenue (Next 12 Months)')

# Add labels and title
plt.xlabel('Month Number', fontsize=14, fontweight='bold')
plt.ylabel('Total Sales Revenue (USD)', fontsize=14, fontweight='bold')
plt.title('Monthly Sales Revenue Forecast', fontsize=18, fontweight='bold', pad=20)

# Customize the legend
plt.legend(loc='upper left', fontsize=12, frameon=True, shadow=True, borderpad=1)

# Add grid for better readability
plt.grid(visible=True, linestyle='--', alpha=0.7)

# Add annotations for the forecasted values
for index, row in forecast_df.iterrows():
    plt.text(row['Month_Number'], row['Forecast_Sales_Revenue'], 
             f"${row['Forecast_Sales_Revenue']:,.0f}", 
             fontsize=10, color='#ff7f0e', ha='center', va='bottom')

# Add a vertical line to separate historical and forecasted data
plt.axvline(x=9.5, color='gray', linestyle=':', linewidth=2, label='End of Historical Data')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Are there any products that show consistent demand throughout the year?

# Findout consistence products for the year 2022

product_consistency = product_sales[product_sales['Date'] <= '2022-12-31'].groupby(['Product_ID' , 'Product_Name'])['Units'].agg(Avg_unit_sold = 'mean',
                                                                                       StdDev_unit_sold = 'std').reset_index()

product_consistency['Coefficient_of_Variation'] = round(product_consistency['StdDev_unit_sold'] / product_consistency['Avg_unit_sold'],1)

# Filter products with consistent demand (Coeff_of_Variation < 0.4)

product_consistency = product_consistency[product_consistency['Coefficient_of_Variation'] < 0.4]


print("Hence the Consistence Demanding Products for year 2022 are: ")

product_consistency.sort_values(by = 'Coefficient_of_Variation', ascending = True)
# Out:
# Hence the Consistence Demanding Products for year 2022 are:
#     Product_ID          Product_Name  Avg_unit_sold  StdDev_unit_sold  \
# 3            4      Chutes & Ladders       1.017914          0.161358
# 18          20  Mini Basketball Hoop       1.024175          0.208957
# 26          29            Plush Pony       1.015453          0.153181
# 4            5      Classic Dominoes       1.050876          0.281388
# 10          11         Etch A Sketch       1.092433          0.381918
# 24          26       PlayDoh Playset       1.049408          0.292760
# 30          33            Teddy Bear       1.041016          0.276949
# 32          35         Uno Card Game       1.059662          0.305917
#
#     Coefficient_of_Variation
# 3                        0.2
# 18                       0.2
# 26                       0.2
# 4                        0.3
# 10                       0.3
# 24                       0.3
# 30                       0.3
# 32                       0.3

# %%
# Findout consistence products for year 2023

# Findout for the year 2022

product_consistency = product_sales[product_sales['Date'] >= '2023-01-01'].groupby(['Product_ID' , 'Product_Name'])['Units'].agg(Avg_unit_sold = 'mean',
                                                                                       StdDev_unit_sold = 'std').reset_index()

product_consistency['Coefficient_of_Variation'] = round(product_consistency['StdDev_unit_sold'] / product_consistency['Avg_unit_sold'],1)

# Filter products with consistent demand (Coeff_of_Variation < 0.4)

product_consistency = product_consistency[product_consistency['Coefficient_of_Variation'] < 0.4]

print("Hence the Consistence Demanding Products for year 2023 are: ")

product_consistency.sort_values(by = 'Coefficient_of_Variation' , ascending = True)
# Out:
# Hence the Consistence Demanding Products for year 2023 are:
#     Product_ID           Product_Name  Avg_unit_sold  StdDev_unit_sold  \
# 21          22               Monopoly       1.007366          0.104891
# 4            5       Classic Dominoes       1.042758          0.260172
# 15          16                  Jenga       1.018163          0.170708
# 19          20   Mini Basketball Hoop       1.027088          0.216155
# 25          26        PlayDoh Playset       1.023024          0.202308
# 34          35          Uno Card Game       1.029810          0.230972
# 3            4       Chutes & Ladders       1.052719          0.290505
# 22          23         Mr. Potatohead       1.082953          0.372752
# 26          27        PlayDoh Toolkit       1.072659          0.366874
# 28          29             Plush Pony       1.047599          0.281615
# 31          32  Supersoaker Water Gun       1.093305          0.381770
#
#     Coefficient_of_Variation
# ...

# %% [markdown]
# # 6. Operational Efficiency Analysis Section:-

# %%
#  How does the store opening date impact sales performance? 


store_wise_sales = store_product_sales.groupby(['Store_ID','Store_Name','Store_Open_Date'])['Sales_Revenue'].sum().reset_index()

store_wise_sales.columns = ['Store_ID','Store_Name','Store_Open_Date','Total_Sales_Revenue']

store_wise_sales['Age'] = ((pd.to_datetime('2024-01-01') - store_wise_sales['Store_Open_Date']).dt.days // 365)

'''
Calculating correlation between store age and its sales performance 
to find the impact of store opening date in sales performance

'''
correlation_result = store_wise_sales['Total_Sales_Revenue'].corr(store_wise_sales['Age'])

print("Hence the Required Correlation Between Store Age and Total Sales Revenue made by each store is : ", round(correlation_result,1))
# Out:
# Hence the Required Correlation Between Store Age and Total Sales Revenue made by each store is :  -0.0

# %%
#  Are newer stores performing better or worse than older stores? 

def findout_store_type(age):
    if age <= 10:
        return 'New_Store'
    else:
        return 'Old_Store'
    
store_wise_sales['Store_Type'] = store_wise_sales['Age'].apply(findout_store_type) 

store_type_performance = store_wise_sales.groupby('Store_Type')['Total_Sales_Revenue'].sum().reset_index()

store_type_performance.columns = ['Store_Type' , 'Total_Sales_Revenue']

store_type_performance.sort_values(by = 'Total_Sales_Revenue', ascending = False)
# Out:
#   Store_Type  Total_Sales_Revenue
# 1  Old_Store           9280017.49
# 0  New_Store           5164554.86
